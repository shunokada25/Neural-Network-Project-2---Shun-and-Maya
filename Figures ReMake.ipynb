# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

classes = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]

cm_before = np.array([
    [81.70, 1.50, 4.20, 1.30, 1.80, 0.60, 0.60, 1.40, 5.30, 1.60],
    [2.40, 87.60, 0.10, 1.10, 0.40, 0.60, 0.70, 0.20, 1.90, 5.00],
    [6.10, 0.40, 69.70, 3.20, 9.60, 4.90, 3.10, 1.90, 0.60, 0.50],
    [2.20, 0.50, 8.20, 53.60, 10.40, 15.20, 3.80, 4.10, 1.00, 1.00],
    [1.20, 0.10, 5.30, 2.70, 81.10, 3.20, 1.30, 4.50, 0.50, 0.10],
    [0.80, 0.30, 6.30, 13.80, 6.80, 64.30, 1.60, 5.70, 0.40, 0.00],
    [0.70, 0.40, 6.70, 6.60, 7.40, 1.80, 74.60, 1.00, 0.70, 0.10],
    [1.70, 0.00, 2.80, 2.10, 7.10, 4.30, 0.20, 81.20, 0.10, 0.50],
    [6.40, 2.20, 1.70, 0.90, 1.20, 0.60, 0.50, 0.30, 85.00, 1.20],
    [4.10, 9.50, 0.80, 0.90, 0.40, 0.40, 0.20, 1.50, 2.80, 79.40]
])

plt.figure(figsize=(10, 8))

sns.heatmap(
    cm_before,
    annot=True,
    fmt=".2f",
    xticklabels=classes,
    yticklabels=classes,
    cmap="Blues",
    cbar = False,
    annot_kws={"size": 16, "weight": "bold"}  # values font size + bold
)

plt.xlabel("Predicted", fontsize=16, fontweight='bold')
plt.ylabel("Actual", fontsize=16, fontweight='bold')
plt.title("Confusion Matrix - CNN (before augmentation)", fontsize=18, fontweight='bold')
plt.xticks(rotation=45, fontsize=12)
plt.yticks(rotation=45, fontsize=12)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

classes = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]

cm_after = np.array([
    [77.20, 2.35, 3.15, 2.10, 1.75, 0.45, 1.05, 1.30, 9.10, 1.55],
    [1.70, 89.90, 0.45, 0.60, 0.95, 0.25, 0.95, 0.30, 2.50, 2.40],
    [8.35, 1.00, 55.15, 6.80, 12.30, 4.00, 7.00, 2.90, 1.25, 0.45],
    [2.70, 1.60, 4.80, 53.70, 9.45, 14.30, 7.90, 3.40, 1.25, 0.90],
    [2.35, 0.50, 5.55, 3.85, 73.00, 2.90, 5.15, 5.80, 0.75, 0.15],
    [1.25, 0.65, 4.60, 18.25, 6.90, 58.70, 2.60, 5.90, 0.60, 0.55],
    [1.00, 0.45, 3.75, 6.15, 6.25, 2.15, 79.05, 0.40, 0.65, 0.15],
    [2.65, 0.70, 2.35, 4.85, 8.90, 4.25, 1.20, 73.75, 0.40, 0.95],
    [8.90, 5.35, 1.25, 1.70, 1.80, 0.30, 0.85, 0.70, 77.00, 1.45],
    [4.50, 15.30, 0.85, 2.20, 0.70, 0.45, 1.25, 2.20, 3.45, 69.10]
])

plt.figure(figsize=(10, 8))

sns.heatmap(
    cm_after,
    annot=True,
    fmt=".2f",
    xticklabels=classes,
    yticklabels=classes,
    cmap="Blues",
    cbar = False,
    annot_kws={"size": 16, "weight": "bold"}  # values font size + bold
)

plt.xlabel("Predicted", fontsize=16, fontweight='bold')
plt.ylabel("Actual", fontsize=16, fontweight='bold')
plt.title("Confusion Matrix - CNN (after augmentation)", fontsize=18, fontweight='bold')
plt.xticks(rotation=45, fontsize=12)
plt.yticks(rotation=45, fontsize=12)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

classes = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]

cm_averaged_hybrid = np.array([
    [90.1, 0.6, 2.4, 0.4, 0.4, 0.5, 0.3, 1.2, 3.7, 0.4],
    [0.6, 95.2, 0.4, 0.2, 0.0, 0.0, 0.2, 0.9, 1.2, 1.3],
    [3.1, 0.2, 84.5, 1.0, 3.7, 2.3, 1.9, 2.7, 0.4, 0.2],
    [1.1, 0.7, 4.9, 67.7, 3.4, 11.4, 3.7, 5.4, 1.3, 0.4],
    [1.0, 0.0, 4.3, 1.7, 81.8, 2.5, 2.3, 6.2, 0.2, 0.0],
    [0.4, 0.1, 3.1, 4.7, 2.4, 83.5, 1.3, 4.1, 0.4, 0.0],
    [0.1, 0.2, 2.4, 2.4, 2.0, 1.1, 91.0, 0.3, 0.5, 0.0],
    [0.3, 0.0, 0.9, 0.4, 0.8, 2.1, 0.1, 95.1, 0.2, 0.1],
    [1.7, 0.5, 0.5, 0.3, 0.2, 0.2, 0.6, 0.4, 95.3, 0.3],
    [1.9, 2.6, 0.4, 0.3, 0.2, 0.5, 0.2, 1.8, 1.7, 90.4]
])

plt.figure(figsize=(10, 8))

sns.heatmap(
    cm_averaged_hybrid,
    annot=True,
    fmt=".1f",
    xticklabels=classes,
    yticklabels=classes,
    cmap="Blues",
    cbar=True,
    annot_kws={"size": 16, "weight": "bold"}
)

plt.xlabel("Predicted Label", fontsize=14)
plt.ylabel("True Label", fontsize=14)
plt.title("Confusion Matrix - Averaged Hybrid Model", fontsize=18, fontweight="bold")

plt.xticks(rotation=45, fontsize=12)
plt.yticks(rotation=0, fontsize=12)

plt.tight_layout()
plt.show()
